# %%
import numpy as np
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
import re
# from textblob import TextBlob
# from wordcloud import WordCloud
import seaborn as sns
# import matplotlib.pyplot as plt
# import cufflinks as cf
# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df = pd.read_csv("Usable_data.csv")

# %%
df.head()
# Out:
#    Sno.                                            Comment  \
# 0   NaN                                                NaN
# 1   NaN                                                NaN
# 2   NaN                                                NaN
# 3   1.0                                                NaN
# 4   2.0  they did not accept one of the certificate and...
#
#                                 Overall Experience\t
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                      good,improved knowledgeof lab
# 4   liked the team and they provide fruitful sugg...

# %%
data = df[df['Overall Experience\t'].notna()]

# %%
data.head()
# Out:
#    Sno.                                            Comment  \
# 3   1.0                                                NaN
# 4   2.0  they did not accept one of the certificate and...
# 5   3.0                                                NaN
# 6   4.0                                                NaN
# 8   6.0                                                NaN
#
#                                 Overall Experience\t
# 3                      good,improved knowledgeof lab
# 4   liked the team and they provide fruitful sugg...
# 5  extraordinary knowledge regarding the paramete...
# 6                        very good with those people
# 8                                  its fine fanastic

# %%
data.shape
data.columns
# Out:
# Index(['Sno.', 'Comment', 'Overall Experience\t'], dtype='object')

# %%
#create a new data frame with "id" and "comment" fields
df_subset = data[['Sno.', 'Overall Experience\t']].copy()
#data clean-up
#remove all non-aphabet characters
df_subset['Overall Experience\t'] = df_subset['Overall Experience\t'].str.replace("[^a-zA-Z#]", " ")
#covert to lower-case
df_subset['Overall Experience\t'] = df_subset['Overall Experience\t'].str.casefold()
print (df_subset.head(10))
# Out:
#     Sno.                               Overall Experience\t
# 3    1.0                      good improved knowledgeof lab
# 4    2.0   liked the team and they provide fruitful sugg...
# 5    3.0  extraordinary knowledge regarding the paramete...
# 6    4.0                        very good with those people
# 8    6.0                                  its fine fanastic
# 10   8.0  hybrid mode requires to prepare lot of the thi...
# 11   9.0
# 12  10.0  over all  experience was good all the assessor...
# 13  11.0                                        it was good
# 14  12.0                                         it was ok
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_5068/1401701387.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_subset['Overall Experience\t'] = df_subset['Overall Experience\t'].str.replace("[^a-zA-Z#]", " ")

# %%
# set up empty dataframe for staging output
df1=pd.DataFrame()
df1['Sno.']=['99999999999']
df1['sentiment_type']='NA999NA'
df1['sentiment_score']=0

# %%
print('Processing sentiment analysis...')
sid = SentimentIntensityAnalyzer()
t_df = df1
for index, row in df_subset.iterrows():
    scores = sid.polarity_scores(row[1])
    for key, value in scores.items():
        temp = [key,value,row[0]]
        df1['Sno.']=row[0]
        df1['sentiment_type']=key
        df1['sentiment_score']=value
        t_df=t_df.append(df1)
#remove dummy row with row_id = 99999999999
t_df_cleaned = t_df[t_df['Sno.'] != '99999999999']
#remove duplicates if any exist
t_df_cleaned = t_df_cleaned.drop_duplicates()
# only keep rows where sentiment_type = compound
t_df_cleaned = t_df[t_df.sentiment_type == 'compound']
print(t_df_cleaned.head(10))
# Out:
# Processing sentiment analysis...
#    Sno. sentiment_type  sentiment_score
# 0   1.0       compound           0.7184
# 0   2.0       compound           0.4215
# 0   3.0       compound           0.4927
# 0   4.0       compound           0.4927
# 0   6.0       compound           0.2023
# 0   8.0       compound           0.0000
# 0   9.0       compound           0.0000
# 0  10.0       compound           0.4404
# 0  11.0       compound           0.4404
# 0  12.0       compound           0.2960

# %%
df_output = pd.merge(df_subset, t_df_cleaned, on='Sno.', how='inner')
print(df_output.head(10))
# Out:
#    Sno.                               Overall Experience\t sentiment_type  \
# 0   1.0                      good improved knowledgeof lab       compound
# 1   2.0   liked the team and they provide fruitful sugg...       compound
# 2   3.0  extraordinary knowledge regarding the paramete...       compound
# 3   4.0                        very good with those people       compound
# 4   6.0                                  its fine fanastic       compound
# 5   8.0  hybrid mode requires to prepare lot of the thi...       compound
# 6   9.0                                                          compound
# 7  10.0  over all  experience was good all the assessor...       compound
# 8  11.0                                        it was good       compound
# 9  12.0                                         it was ok        compound
#
#    sentiment_score
# 0           0.7184
# 1           0.4215
# 2           0.4927
# 3           0.4927
# 4           0.2023
# 5           0.0000
# 6           0.0000
# 7           0.4404
# 8           0.4404
# 9           0.2960

# %%
sns.distplot(df_output['sentiment_score'])
# Out:
# C:\Users\Lenovo\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sentiment_score', ylabel='Density'>

# %%
# Set a default value
df_output['Sentiment'] = '0'
# Set Age_Group value for all row indexes which Age are greater than 40
df_output['Sentiment'][df_output['sentiment_score'] < 0.2] = 'Negative'
# Set Age_Group value for all row indexes which Age are greater than 18 and < 40
df_output['Sentiment'][(df_output['sentiment_score'] > 0.2) & (df_output['sentiment_score'] < 0.6)] = 'Neutral'
# Set Age_Group value for all row indexes which Age are less than 18
df_output['Sentiment'][df_output['sentiment_score'] > 0.6] = 'Positive'
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_5068/1906902956.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_output['Sentiment'][df_output['sentiment_score'] < 0.2] = 'Negative'
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_5068/1906902956.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_output['Sentiment'][(df_output['sentiment_score'] > 0.2) & (df_output['sentiment_score'] < 0.6)] = 'Neutral'
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_5068/1906902956.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_output['Sentiment'][df_output['sentiment_score'] > 0.6] = 'Positive'

# %%
df_output.head(10)
# Out:
#    Sno.                               Overall Experience\t sentiment_type  \
# 0   1.0                      good improved knowledgeof lab       compound
# 1   2.0   liked the team and they provide fruitful sugg...       compound
# 2   3.0  extraordinary knowledge regarding the paramete...       compound
# 3   4.0                        very good with those people       compound
# 4   6.0                                  its fine fanastic       compound
# 5   8.0  hybrid mode requires to prepare lot of the thi...       compound
# 6   9.0                                                          compound
# 7  10.0  over all  experience was good all the assessor...       compound
# 8  11.0                                        it was good       compound
# 9  12.0                                         it was ok        compound
#
#    sentiment_score Sentiment
# 0           0.7184  Positive
# 1           0.4215   Neutral
# 2           0.4927   Neutral
# 3           0.4927   Neutral
# 4           0.2023   Neutral
# 5           0.0000  Negative
# 6           0.0000  Negative
# 7           0.4404   Neutral
# 8           0.4404   Neutral
# 9           0.2960   Neutral

# %%
print(df_output['Sentiment'].value_counts())
# Out:
# Neutral     908
# Positive    166
# Negative     52
# Name: Sentiment, dtype: int64

# %%
df_output.loc[df_output['Sentiment'] == 'Negative']
# Out:
#         Sno.                               Overall Experience\t  \
# 5        8.0  hybrid mode requires to prepare lot of the thi...
# 6        9.0
# 33      39.0  excellent  but only thing we found odd was tha...
# 63      79.0  fine  the process is very slow and nabl site d...
# 71      91.0  it was good but we have a issue that nabl shou...
# 108    141.0  very knowledgeable  the assessors did their wo...
# 114    147.0                                       wrong number
# 166    212.0  the audit was done successfully with the coope...
# 171    218.0  it was not pleasant at all  the auditors were ...
# 178    226.0                        experience was satsfactory
# 197    247.0  assessment process was good  there are two thi...
# 216    271.0                                           very bad
# 218    274.0  it was good  the assessors were very professio...
# 225    284.0                                 worst experience
# 231    290.0                                         it was bad
# 250    315.0                              it was dissopointing
# 298    378.0                         experience was knowlwdgale
# 316    403.0  it was fine  the assessors were mentioning the...
# 342    436.0  it was good but because of unfortunate circums...
# 362    461.0  it was good  but we have faced one problem tha...
# 401    512.0  both assessors were very knowledgeable and als...
# 404    515.0                                   it was not good
# 478    607.0                                   it was excelent
# 479    608.0  it was not a good experience and want nabl to ...
# 484    614.0  client said that after      it was their first...
# 519    660.0                                     no experience
# 555    705.0  it was very learning process and knowledgeable...
# 626    788.0            it was fine their were no problem faced
# 650    819.0                                     unsatisfactory
# 671    848.0  itwas completely learning process it was condu...
# 675    853.0  lab s people were unsatisfied with the lead as...
# 732    921.0  very detailed identification assessment was th...
# 742    934.0                            very nice   no problem
# 744    937.0                                       wrong number
# 747    940.0   unsatisfactory  and poor experience of this a...
# 802   1008.0  it is quite in depth audit from last time abso...
# 823   1032.0                                   worst experience
# 838   1049.0              split assessment should not be there
# 843   1055.0                                             years
# 846   1059.0  fed up with opening meeting few arguements wer...
# 858   1074.0  we did not feel good with how the assessment w...
# 912   1135.0  excellent  only we faced problem because of la...
# 964   1198.0  good learning experience  staff was facing pro...
# 977   1211.0                  it was an eye opening experience
# 983   1219.0                           experience was not good
# 990   1226.0  every time assessors have different point of v...
# 998   1237.0  except one assessor  mr  deshpandey  all were ...
# 1012  1255.0                                exclent experience
# 1020  1264.0  it was very good  assessors had deep knowledge...
# 1033  1283.0  it was a     assessment  everything was well p...
# 1051  1302.0                     unsatisfactory at some points
# 1090  1347.0  assessment was conducted professionally  asses...
#
#      sentiment_type  sentiment_score Sentiment
# 5          compound           0.0000  Negative
# 6          compound           0.0000  Negative
# 33         compound          -0.1531  Negative
# 63         compound          -0.0018  Negative
# 71         compound          -0.2144  Negative
# 108        compound           0.0000  Negative
# 114        compound          -0.4215  Negative
# 166        compound           0.1280  Negative
# 171        compound          -0.5566  Negative
# 178        compound           0.0000  Negative
# 197        compound          -0.4588  Negative
# 216        compound          -0.5849  Negative
# 218        compound          -0.2805  Negative
# 225        compound          -0.6249  Negative
# 231        compound          -0.5423  Negative
# 250        compound           0.0000  Negative
# 298        compound           0.0000  Negative
# 316        compound          -0.3400  Negative
# 342        compound          -0.5859  Negative
# 362        compound          -0.6315  Negative
# 401        compound           0.0000  Negative
# 404        compound          -0.3412  Negative
# 478        compound           0.0000  Negative
# 479        compound          -0.2746  Negative
# 484        compound          -0.2755  Negative
# 519        compound          -0.2960  Negative
# 555        compound           0.0000  Negative
# 626        compound          -0.4767  Negative
# 650        compound           0.0000  Negative
# 671        compound           0.0000  Negative
# 675        compound          -0.5873  Negative
# 732        compound           0.0000  Negative
# 742        compound          -0.3289  Negative
# 744        compound          -0.4215  Negative
# 747        compound          -0.4767  Negative
# 802        compound           0.0000  Negative
# 823        compound          -0.6249  Negative
# 838        compound           0.0000  Negative
# 843        compound           0.0000  Negative
# 846        compound           0.0000  Negative
# 858        compound          -0.5432  Negative
# 912        compound           0.1280  Negative
# 964        compound           0.0516  Negative
# 977        compound           0.0000  Negative
# 983        compound          -0.3412  Negative
# 990        compound           0.0000  Negative
# 998        compound           0.0000  Negative
# 1012       compound           0.0000  Negative
# 1020       compound          -0.2529  Negative
# 1033       compound           0.1280  Negative
# 1051       compound           0.0000  Negative
# 1090       compound           0.0000  Negative
